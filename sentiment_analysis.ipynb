# %%
import pandas as pd

print("Pandas funcionando!")
# Out:
# Pandas funcionando!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-86652752-0967-4d83-986d-bb98c43c178c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86652752-0967-4d83-986d-bb98c43c178c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Pasta(Planilha1) (1).csv", sep=";")

df.head()
# Out:
#    ID                                            Comment Sentiment  \
# 0   1  AI will definitely replace many repetitive job...  Positive
# 1   2  I am scared that AI will take away entry-level...  Negative
# 2   3  AI can help humans focus on more creative and ...  Positive
# 3   4  I don’t trust companies using AI to replace wo...  Negative
# 4   5  Not sure if AI is a threat or just another too...   Neutral
#
#             Topic
# 0  Job Automation
# 1  Job Automation
# 2  Future of Work
# 3          Ethics
# 4     Uncertainty

# %%
print(df.shape)
#Ver o tamanho da base
# Out:
# (99, 4)

# %%
#Ver as colunas
print(df.columns)
# Out:
# Index(['ID', 'Comment', 'Sentiment', 'Topic'], dtype='object')

# %%
#Contar sentimentos
print(df["Sentiment"].value_counts())
# Out:
# Sentiment
# Negative    46
# Positive    38
# Neutral     15
# Name: count, dtype: int64

# %%
#Ver os tópicos mais frequentes
print(df["Topic"].value_counts())
# Out:
# Topic
# Remote Work             5
# Job Automation          3
# Inequality              3
# Education               2
# Policy                  2
#                        ..
# Human Skills            1
# Human Adaptation        1
# Technological Change    1
# Future Jobs             1
# AI Readiness            1
# Name: count, Length: 82, dtype: int64

# %%
#Fazer seu primeiro gráfico
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.show()
plt.savefig("grafico1.png", dpi=300, bbox_inches="tight")

# %%
print(df["Sentiment"].value_counts())
# Out:
# Sentiment
# Negative    46
# Positive    38
# Neutral     15
# Name: count, dtype: int64

# %%
#topico mais comentado
print(df["Topic"].value_counts())
# Out:
# Topic
# Remote Work             5
# Job Automation          3
# Inequality              3
# Education               2
# Policy                  2
#                        ..
# Human Skills            1
# Human Adaptation        1
# Technological Change    1
# Future Jobs             1
# AI Readiness            1
# Name: count, Length: 82, dtype: int64

# %%
print(df.shape)
# Out:
# (99, 4)

# %%
print(df["Sentiment"].isna().sum())
# Out:
# 0

# %%
topic_mapping = {
    # Job-related
    "Job Automation": "Job Market",
    "Job Loss": "Job Market",
    "Job Displacement": "Job Market",
    "Job Replacement": "Job Market",
    "Job Security": "Job Market",
    "Job Market Future": "Job Market",
    "HR Automation": "Job Market",
    "Hiring Automation": "Job Market",
    "Future Jobs": "Job Market",

    # Skills
    "Soft Skills": "Skills",
    "Human Skills": "Skills",
    "Career Adaptation": "Skills",
    "Education": "Skills",
    "Education & Skills": "Skills",
    "Career Reflection": "Skills",
    "Upskilling Debate": "Skills",

    # Economy
    "Inequality": "Economy",
    "Cost of Living": "Economy",
    "Economic Impact": "Economy",
    "Wages": "Economy",
    "Universal Basic Income": "Economy",

    # Technology
    "Technology": "Technology",
    "AI Readiness": "Technology",
    "Technological Change": "Technology",
    "AI Future": "Technology",
    "AI Tools": "Technology",
    "AI Performance": "Technology",

    # Work
    "Remote Work": "Work",
    "Workplace Impact": "Work",

    # Policy
    "Policy": "Policy",
    "Policy / Regulation": "Policy",
    "AI Governance": "Policy",

    # Human
    "Healthcare": "Human Roles",
    "Human-Centered Jobs": "Human Roles",
    "Skilled Trades": "Human Roles",
    "Infrastructure Jobs": "Human Roles"
}

# %%
import pandas as pd

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'Pasta(Planilha1) (1).csv', 'sample_data']

# %%
df = pd.read_csv("Pasta(Planilha1) (1).csv", sep=";")

# %%
import matplotlib.pyplot as plt

df["Sentiment"].value_counts().plot(kind="bar")

plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Number of Comments")

plt.show()

# %%
df["Topic"].value_counts()
# Out:
# Topic
# Remote Work             5
# Job Automation          3
# Inequality              3
# Education               2
# Policy                  2
#                        ..
# Human Skills            1
# Human Adaptation        1
# Technological Change    1
# Future Jobs             1
# AI Readiness            1
# Name: count, Length: 82, dtype: int64

# %%
pd.crosstab(df["Main_Topic"], df["Sentiment"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Main_Topic'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2826/4293696596.py in <cell line: 0>()
# ----> 1 pd.crosstab(df["Main_Topic"], df["Sentiment"])
#
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Comment', 'Sentiment', 'Topic'], dtype='object')

# %%
df["Main_Topic"] = df["Topic"].replace(topic_mapping)

# %%
pd.crosstab(df["Main_Topic"], df["Sentiment"])
# Out:
# Sentiment                 Negative  Neutral  Positive
# Main_Topic
# AI Costs                         1        0         0
# AI Dependence                    1        0         0
# AI Ethics / Conflict             1        0         0
# AI Recruitment                   0        1         0
# Accessibility                    1        0         0
# Adaptability                     0        0         1
# Adaptation Anxiety               1        0         0
# Automation Benefits              0        0         1
# Balanced View                    0        1         0
# Business Productivity            0        0         1
# Career Advice                    0        0         1
# Creative Work                    0        0         1
# Economic Concern                 1        0         0
# Economy                          7        0         0
# Education & Labor Market         0        1         0
# Entrepreneurship                 0        0         1
# ...

# %%
pd.crosstab(df["Main_Topic"], df["Sentiment"])
# Out:
# Sentiment                 Negative  Neutral  Positive
# Main_Topic
# AI Costs                         1        0         0
# AI Dependence                    1        0         0
# AI Ethics / Conflict             1        0         0
# AI Recruitment                   0        1         0
# Accessibility                    1        0         0
# Adaptability                     0        0         1
# Adaptation Anxiety               1        0         0
# Automation Benefits              0        0         1
# Balanced View                    0        1         0
# Business Productivity            0        0         1
# Career Advice                    0        0         1
# Creative Work                    0        0         1
# Economic Concern                 1        0         0
# Economy                          7        0         0
# Education & Labor Market         0        1         0
# Entrepreneurship                 0        0         1
# ...

# %%
import matplotlib.pyplot as plt

df["Main_Topic"].value_counts().plot(kind="bar", figsize=(10,5))

plt.title("Distribution of Main Topics")
plt.xlabel("Main Topic")
plt.ylabel("Number of Comments")
plt.xticks(rotation=45)

plt.show()
plt.savefig("grafico1.png", dpi=300, bbox_inches="tight")

# %%
plt.savefig("grafico1.png", dpi=300, bbox_inches="tight")
